# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Maaruboina Vamsi'

# %%
import os
os.path.abspath("Healthcare Providers.csv")
# Out:
# 'C:\\Users\\Maaruboina Vamsi\\Healthcare Providers.csv'

# %%
import pandas as pd

# Load CSV file
df = pd.read_csv('Healthcare Providers.csv')

# View first few rows
df.head()
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# ...

# %%
# df.info()
df.columns
# Out:
# Index(['index', 'National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
pd.read_csv("Healthcare Providers.csv",nrows=0)
# Out:
# Empty DataFrame
# Columns: [index, National Provider Identifier, Last Name/Organization Name of the Provider, First Name of the Provider, Middle Initial of the Provider, Credentials of the Provider, Gender of the Provider, Entity Type of the Provider, Street Address 1 of the Provider, Street Address 2 of the Provider, City of the Provider, Zip Code of the Provider, State Code of the Provider, Country Code of the Provider, Provider Type, Medicare Participation Indicator, Place of Service, HCPCS Code, HCPCS Description, HCPCS Drug Indicator, Number of Services, Number of Medicare Beneficiaries, Number of Distinct Medicare Beneficiary/Per Day Services, Average Medicare Allowed Amount, Average Submitted Charge Amount, Average Medicare Payment Amount, Average Medicare Standardized Amount]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.shape
# Out:
# (100000, 27)

# %%
a=pd.DataFrame([1,2,3,4,5])
a
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df.describe()
# Out:
#               index  National Provider Identifier  Zip Code of the Provider
# count  1.000000e+05                  1.000000e+05              1.000000e+05
# mean   4.907646e+06                  1.498227e+09              4.163820e+08
# std    2.839633e+06                  2.874125e+08              3.082566e+08
# min    2.090000e+02                  1.003001e+09              6.010000e+02
# 25%    2.458791e+06                  1.245669e+09              1.426300e+08
# 50%    4.901266e+06                  1.497847e+09              3.633025e+08
# 75%    7.349450e+06                  1.740374e+09              6.819881e+08
# max    9.847440e+06                  1.993000e+09              9.990166e+08

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          index  National Provider Identifier  \
# 0      8774979                    1891106191
# 1      3354385                    1346202256
# 2      3001884                    1306820956
# 3      7594822                    1770523540
# 4       746159                    1073627758
# ...        ...                           ...
# 99995  3837311                    1386938868
# 99996  2079360                    1215091327
# 99997  8927965                    1902868185
# 99998  8854571                    1891941183
# 99999  3547535                    1356772156
#
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                     UPADHYAYULA                  SATYASREE
# 1                                           JONES                      WENDY
# 2                                        DUROCHER                    RICHARD
# ...

# %%
df
# Out:
#          index  National Provider Identifier  \
# 0      8774979                    1891106191
# 1      3354385                    1346202256
# 2      3001884                    1306820956
# 3      7594822                    1770523540
# 4       746159                    1073627758
# ...        ...                           ...
# 99995  3837311                    1386938868
# 99996  2079360                    1215091327
# 99997  8927965                    1902868185
# 99998  8854571                    1891941183
# 99999  3547535                    1356772156
#
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                     UPADHYAYULA                  SATYASREE
# 1                                           JONES                      WENDY
# 2                                        DUROCHER                    RICHARD
# 3                                         FULLARD                     JASPER
# ...

# %%
df["index"]
# Out:
# 0        8774979
# 1        3354385
# 2        3001884
# 3        7594822
# 4         746159
#           ...
# 99995    3837311
# 99996    2079360
# 99997    8927965
# 99998    8854571
# 99999    3547535
# Name: index, Length: 100000, dtype: int64

# %%
df["index"].describe()
# Out:
# count    1.000000e+05
# mean     4.907646e+06
# std      2.839633e+06
# min      2.090000e+02
# 25%      2.458791e+06
# 50%      4.901266e+06
# 75%      7.349450e+06
# max      9.847440e+06
# Name: index, dtype: float64

# %%
df["index"].mean()
# Out:
# 4907645.74603

# %%
df["index"].median()
# Out:
# 4901266.0

# %%
df["index"].mode()
# Out:
# 0            209
# 1            390
# 2            435
# 3            446
# 4            493
#           ...
# 99995    9847188
# 99996    9847250
# 99997    9847379
# 99998    9847437
# 99999    9847440
# Name: index, Length: 100000, dtype: int64

# %%
df['First Name of the Provider'].value_counts()
# Out:
# First Name of the Provider
# MICHAEL     2350
# JOHN        2285
# DAVID       2239
# ROBERT      1872
# JAMES       1647
#             ...
# PACIFICO       1
# NANTHA         1
# SAMUAL         1
# DENAYE         1
# ELIIAN         1
# Name: count, Length: 13022, dtype: int64

# %%
df['First Name of the Provider'].unique()
# Out:
# array(['SATYASREE', 'WENDY', 'RICHARD', ..., 'ILIE', 'RAFAELA', 'ELIIAN'],
#       dtype=object)

# %%
df['First Name of the Provider'].loc[1:30].unique()
# Out:
# array(['WENDY', 'RICHARD', 'JASPER', 'ANTHONY', 'JOHN', 'TOM', 'RONALD',
#        'RALPH', nan, 'LAUREN', 'ERIC', 'MUKESH', 'BABAK', 'GAURAV', 'AMY',
#        'MARIA', 'AARON', 'GREGORY', 'EDWARD', 'MICHAEL', 'SILVIA', 'AMIT',
#        'KELLY', 'WALTER', 'DAVID', 'STEPHEN', 'ROBERT', 'PHILIP', 'FEBIN'],
#       dtype=object)

# %%
df['First Name of the Provider'].iloc[1:30].unique()
# Out:
# array(['WENDY', 'RICHARD', 'JASPER', 'ANTHONY', 'JOHN', 'TOM', 'RONALD',
#        'RALPH', nan, 'LAUREN', 'ERIC', 'MUKESH', 'BABAK', 'GAURAV', 'AMY',
#        'MARIA', 'AARON', 'GREGORY', 'EDWARD', 'MICHAEL', 'SILVIA', 'AMIT',
#        'KELLY', 'WALTER', 'DAVID', 'STEPHEN', 'ROBERT', 'PHILIP'],
#       dtype=object)

# %%
print("Missing valuse")
missing_values=df.isnull().sum()
# print(missing_values)
percentages=(missing_values/len(df))*100
dataOfMissingValues=pd.DataFrame({'Missing_Values':missing_values,"Percentages":percentages})
dataOfMissingValues
# Out:
# Missing valuse
#                                                     Missing_Values  \
# index                                                            0
# National Provider Identifier                                     0
# Last Name/Organization Name of the Provider                      0
# First Name of the Provider                                    4255
# Middle Initial of the Provider                               29331
# Credentials of the Provider                                   7209
# Gender of the Provider                                        4254
# Entity Type of the Provider                                      0
# Street Address 1 of the Provider                                 0
# Street Address 2 of the Provider                             59363
# City of the Provider                                             0
# Zip Code of the Provider                                         0
# State Code of the Provider                                       0
# ...

# %%
a=df.dropna()
a.shape
# Out:
# (29346, 27)

# %%
df.shape
# Out:
# (100000, 27)
