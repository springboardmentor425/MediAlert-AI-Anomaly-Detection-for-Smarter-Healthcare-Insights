# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
import numpy as np
import category_encoders as ce
df = pd.read_csv('Healthcare Providers.csv')

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\anaconda\lib\site-packages (2.6.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from category_encoders) (1.26.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from category_encoders) (1.6.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from category_encoders) (1.14.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from category_encoders) (2.1.4)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from pandas>=1.0.5->category_encoders) (2023.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in c:\users\maaruboina vamsi\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.16.0)
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
drop=['index', 'National Provider Identifier',
       'Last Name/Organization Name of the Provider',
       'First Name of the Provider', 'Middle Initial of the Provider','Street Address 1 of the Provider',
       'Street Address 2 of the Provider','Zip Code of the Provider',"HCPCS Code"]

# %%
df = df.drop(columns=drop)

# %%
df.isnull().sum()

# %%
# df['Credentials of the Provider']=df['Credentials of the Provider'].fillna('Unknown')
# gender_mode = df['Gender of the Provider'].mode()[0]
# df['Gender of the Provider'] = df['Gender of the Provider'].fillna(gender_mode)

# %%
# df.isnull().sum()

# %%
# # Ensure the column is of string type before applying string operations
# df['Average Medicare Allowed Amount'] = df['Average Medicare Allowed Amount'].astype(str).str.replace('$', '').str.replace(',', '').astype(float)
# df['Average Submitted Charge Amount'] = df['Average Submitted Charge Amount'].astype(str).str.replace('$', '').str.replace(',', '').astype(float)
# df['Average Medicare Payment Amount'] = df['Average Medicare Payment Amount'].astype(str).str.replace('$', '').str.replace(',', '').astype(float)
# df['Average Medicare Standardized Amount'] = df['Average Medicare Standardized Amount'].astype(str).str.replace('$', '').str.replace(',', '').astype(float)

# %% [markdown]
# Numaric Features

# %%
numerical_features = [
    'Number of Services',
    'Number of Medicare Beneficiaries',
    'Number of Distinct Medicare Beneficiary/Per Day Services',
    'Average Medicare Allowed Amount',
    'Average Submitted Charge Amount',
    'Average Medicare Payment Amount',
    'Average Medicare Standardized Amount'
]

# %% [markdown]
# CLEAN NUMARIC FEATURES

# %%
for i in numerical_features:
    df[i] = df[i].replace({",": ""}, regex=True)  # Remove commas
    df[i] = pd.to_numeric(df[i], errors='coerce')  # Convert to numeric

# %% [markdown]
# Min-Max Scaling

# %%
min_max_scaler = MinMaxScaler()
min_max_scaler.set_output(transform='pandas')  # Ensure output is in Pandas DataFrame
df[numerical_features] = min_max_scaler.fit_transform(df[numerical_features])

# %% [markdown]
# categorical columns

# %%
categorical_features = [
    'Credentials of the Provider',
    'Entity Type of the Provider',
    'City of the Provider',
    'State Code of the Provider',
    'Country Code of the Provider',
    'Provider Type',
    'Medicare Participation Indicator',
    'Place of Service',
    'HCPCS Description',
    'HCPCS Drug Indicator'
]

# %% [markdown]
# Handle missing values in categorical columns

# %%
df[categorical_features] = df[categorical_features].fillna('Unknown')

# %%
threshold = 100  # Example: any category appearing fewer than 100 times will be grouped as 'Other'
for col in categorical_features:
    value_counts = df[col].value_counts()
    rare_categories = value_counts[value_counts < threshold].index
    df[col] = df[col].replace(rare_categories, 'Other')

# %% [markdown]
# One-Hot Encoder

# %%
encoder = ce.OneHotEncoder(cols=categorical_features, use_cat_names=True)#,sparse_output=True)
encoder.set_output(transform='pandas') 
df_encoded = encoder.fit_transform(df)

# %%
'''encoder OneHotEncoder(cols=['Credentials of the Provider',
                    'Entity Type of the Provider', 'City of the Provider',
                    'State Code of the Provider',
                    'Country Code of the Provider', 'Provider Type',
                    'Medicare Participation Indicator', 'Place of Service',
                    'HCPCS Description', 'HCPCS Drug Indicator'],
              use_cat_names=True)'''
# Out:
# "encoder OneHotEncoder(cols=['Credentials of the Provider',\n                    'Entity Type of the Provider', 'City of the Provider',\n                    'State Code of the Provider',\n                    'Country Code of the Provider', 'Provider Type',\n                    'Medicare Participation Indicator', 'Place of Service',\n                    'HCPCS Description', 'HCPCS Drug Indicator'],\n              use_cat_names=True)"

# %% [markdown]
# Label Encoder

# %%
# Step 6: Label Encoding for Binary Categories
label_encoder = LabelEncoder()
df_encoded['Gender of the Provider'] = label_encoder.fit_transform(df_encoded['Gender of the Provider'])

# %%
df_encoded.describe()
# Out:
#        Credentials of the Provider_M.D.  Credentials of the Provider_DPM  \
# count                     100000.000000                    100000.000000
# mean                           0.327570                         0.013300
# std                            0.469329                         0.114557
# min                            0.000000                         0.000000
# 25%                            0.000000                         0.000000
# 50%                            0.000000                         0.000000
# 75%                            1.000000                         0.000000
# max                            1.000000                         1.000000
#
#        Credentials of the Provider_MD  Credentials of the Provider_DO  \
# count                   100000.000000                   100000.000000
# mean                         0.328740                        0.024780
# std                          0.469758                        0.155455
# min                          0.000000                        0.000000
# 25%                          0.000000                        0.000000
# 50%                          0.000000                        0.000000
# 75%                          1.000000                        0.000000
# max                          1.000000                        1.000000
#
#        Credentials of the Provider_DPT  Credentials of the Provider_D.O.  \
# count                    100000.000000                     100000.000000
# mean                          0.006450                          0.035330
# std                           0.080053                          0.184613
# min                           0.000000                          0.000000
# 25%                           0.000000                          0.000000
# 50%                           0.000000                          0.000000
# 75%                           0.000000                          0.000000
# max                           1.000000                          1.000000
#
#        Credentials of the Provider_Unknown  Credentials of the Provider_M.D  \
# count                        100000.000000                    100000.000000
# mean                              0.072090                         0.009350
# std                               0.258638                         0.096243
# min                               0.000000                         0.000000
# 25%                               0.000000                         0.000000
# 50%                               0.000000                         0.000000
# 75%                               0.000000                         0.000000
# max                               1.000000                         1.000000
#
#        Credentials of the Provider_PA-C  Credentials of the Provider_ARNP  \
# count                     100000.000000                     100000.000000
# mean                           0.018590                          0.004630
# std                            0.135073                          0.067887
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            0.000000                          0.000000
# max                            1.000000                          1.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        HCPCS Description_Moderate sedation services by physician also performing a procedure, patient 5 years of age or older, first 15 minutes  \
# count                                      100000.000000
# mean                                            0.001780
# std                                             0.042153
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        HCPCS Drug Indicator_N  HCPCS Drug Indicator_Y  Number of Services  \
# count            100000.00000            100000.00000       100000.000000
# mean                  0.93802                 0.06198            0.000809
# std                   0.24112                 0.24112            0.008818
# min                   0.00000                 0.00000            0.000000
# 25%                   1.00000                 0.00000            0.000035
# 50%                   1.00000                 0.00000            0.000113
# 75%                   1.00000                 0.00000            0.000378
# max                   1.00000                 1.00000            1.000000
#
#        Number of Medicare Beneficiaries  \
# count                     100000.000000
# mean                           0.000414
# std                            0.005831
# min                            0.000000
# 25%                            0.000032
# 50%                            0.000110
# 75%                            0.000336
# max                            1.000000
#
#        Number of Distinct Medicare Beneficiary/Per Day Services  \
# count                                      100000.000000
# mean                                            0.000464
# std                                             0.005801
# min                                             0.000000
# 25%                                             0.000032
# 50%                                             0.000103
# 75%                                             0.000336
# max                                             1.000000
#
#        Average Medicare Allowed Amount  Average Submitted Charge Amount  \
# count                    100000.000000                    100000.000000
# mean                          0.004949                         0.005655
# std                           0.012552                         0.016949
# min                           0.000000                         0.000000
# 25%                           0.001184                         0.000919
# 50%                           0.003176                         0.002329
# 75%                           0.005521                         0.004768
# max                           1.000000                         1.000000
#
#        Average Medicare Payment Amount  Average Medicare Standardized Amount
# count                    100000.000000                         100000.000000
# mean                          0.004814                              0.004601
# std                           0.012430                              0.011797
# min                           0.000000                              0.000000
# 25%                           0.001203                              0.001186
# 50%                           0.002926                              0.002821
# 75%                           0.005283                              0.005005
# max                           1.000000                              1.000000
#
# [8 rows x 562 columns]
