# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
file_path = "C:/Users/Admin/Downloads/archive/Healthcare Providers.csv"
data = pd.read_csv(file_path)

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   index                                                     100000 non-null  int64
#  1   National Provider Identifier                              100000 non-null  int64
#  2   Last Name/Organization Name of the Provider               100000 non-null  object
#  3   First Name of the Provider                                95745 non-null   object
#  4   Middle Initial of the Provider                            70669 non-null   object
#  5   Credentials of the Provider                               92791 non-null   object
#  6   Gender of the Provider                                    95746 non-null   object
# ...

# %%
print(data.columns)
# Out:
# Index(['index', 'National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
provider_counts = data['Average Medicare Allowed Amount'].value_counts()
print(provider_counts)
# Out:
# Average Medicare Allowed Amount
# 3               1017
# 3.08             441
# 13.32            417
# 3.5              406
# 5.39             356
#                 ...
# 10.316414141       1
# 522.33142857       1
# 62.443461538       1
# 2.6002941176       1
# 38.601052632       1
# Name: count, Length: 49629, dtype: int64

# %%
print(data.head())
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# ...

# %%
import pandas as pd
file_path = "C:/Users/Admin/Downloads/archive/Healthcare Providers.csv"
data = pd.read_csv(file_path)

# %%
# Check column names and data types
print(df.info())

# Summary of numerical and categorical columns
print(df.describe())
print(df.describe(include='object'))  # For categorical columns

# Check for missing values
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Check column names and data types
# ----> 2 print(df.info())
#       4 # Summary of numerical and categorical columns
#       5 print(df.describe())
#
# NameError: name 'df' is not defined

# %%
file_path = 'C:/Users/Admin/Downloads/archive/Healthcare Providers.csv'  # Ensure the filename or path is correct
df = pd.read_excel(file_path)  # Reload the dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 file_path = 'C:/Users/Admin/Downloads/archive/Healthcare Providers.csv'  # Ensure the filename or path is correct
# ----> 2 df = pd.read_excel(file_path)
#
# File ~\anaconda3\envs\InfosysIntern\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
import pandas as pd

file_path = 'C:/Users/Admin/Downloads/archive/Healthcare Providers.csv'

# Use read_csv for CSV files
df = pd.read_csv(file_path)

# Verify the dataset is loaded correctly
print(df.head())
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# ...

# %%
# Check column names and data types
print(df.info())

# Summary of numerical and categorical columns
print(df.describe())
print(df.describe(include='object'))  # For categorical columns

# Check for missing values
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   index                                                     100000 non-null  int64
#  1   National Provider Identifier                              100000 non-null  int64
#  2   Last Name/Organization Name of the Provider               100000 non-null  object
#  3   First Name of the Provider                                95745 non-null   object
#  4   Middle Initial of the Provider                            70669 non-null   object
#  5   Credentials of the Provider                               92791 non-null   object
#  6   Gender of the Provider                                    95746 non-null   object
# ...

# %%
# Check for missing values
print(df.isnull().sum())

# Percentage of missing values
print(df.isnull().mean() * 100)
# Out:
# index                                                           0
# National Provider Identifier                                    0
# Last Name/Organization Name of the Provider                     0
# First Name of the Provider                                   4255
# Middle Initial of the Provider                              29331
# Credentials of the Provider                                  7209
# Gender of the Provider                                       4254
# Entity Type of the Provider                                     0
# Street Address 1 of the Provider                                0
# Street Address 2 of the Provider                            59363
# City of the Provider                                            0
# Zip Code of the Provider                                        0
# State Code of the Provider                                      0
# Country Code of the Provider                                    0
# ...

# %%
df['Numerical_Column'].fillna(df['Numerical_Column'].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\InfosysIntern\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Numerical_Column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install pandas matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

file_path = 'C:/Users/Admin/Downloads/archive/Healthcare Providers.csv'

# Use read_csv for CSV files
df = pd.read_csv(file_path)

# Verify the dataset is loaded correctly
print(df.head())
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# ...

# %%
# Check for column names and data types
df.info()

# Display unique values in the provider type column
provider_column = 'Average Medicare Standardized Amount'  # Replace with the actual column name for provider types
df[provider_column].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   index                                                     100000 non-null  int64
#  1   National Provider Identifier                              100000 non-null  int64
#  2   Last Name/Organization Name of the Provider               100000 non-null  object
#  3   First Name of the Provider                                95745 non-null   object
#  4   Middle Initial of the Provider                            70669 non-null   object
#  5   Credentials of the Provider                               92791 non-null   object
#  6   Gender of the Provider                                    95746 non-null   object
# ...

# %%
# Find the most frequent provider type
most_frequent = df[provider_column].mode()[0]

# Fill missing values with the most frequent value
df[provider_column] = df[provider_column].fillna(most_frequent)

print(f"Filled missing values with the most common provider type: {most_frequent}")
# Out:
# Filled missing values with the most common provider type: 25.32

# %%
# Fill missing values with a placeholder
df[provider_column] = df[provider_column].fillna('Unknown')

print("Filled missing values with 'Unknown'")
# Out:
# Filled missing values with 'Unknown'

# %%
print(df.columns)
# Out:
# Index(['index', 'National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
import numpy as np

# Create a probabilistic replacement based on the distribution
prob_distribution = df[provider_column].value_counts(normalize=True)
missing_indices = df[df[provider_column].isnull()].index

# Randomly assign missing values based on the distribution
df.loc[missing_indices, provider_column] = np.random.choice(
    prob_distribution.index, 
    size=len(missing_indices), 
    p=prob_distribution.values
)

print("Filled missing values based on probabilistic distribution")
# Out:
# Filled missing values based on probabilistic distribution

# %%
# Verify that there are no missing values
missing_values_after = df[provider_column].isnull().sum()
print(f"Missing values after filling: {missing_values_after}")
# Out:
# Missing values after filling: 0

# %%
# Count the occurrences of each provider type
provider_distribution = df[provider_column].value_counts()

# Display the distribution
print(provider_distribution)
# Out:
# Average Medicare Standardized Amount
# 25.32           1630
# 2.94             996
# 115.36           501
# 3.02             453
# 13.05            453
#                 ...
# 17.807738095       1
# 382.45380952       1
# 54.401033113       1
# 8.4985             1
# 10.506927083       1
# Name: count, Length: 76237, dtype: int64

# %%
# Most common provider type
most_common = provider_distribution.idxmax()
most_common_count = provider_distribution.max()

print(f"Most common provider type: {most_common} ({most_common_count} occurrences)")

# Least common provider type
least_common = provider_distribution.idxmin()
least_common_count = provider_distribution.min()

print(f"Least common provider type: {least_common} ({least_common_count} occurrences)")
# Out:
# Most common provider type: 25.32 (1630 occurrences)
# Least common provider type: 66.6032 (1 occurrences)

# %%
# Simple bar plot using pandas
provider_distribution.plot(kind='bar', figsize=(10, 6), title='Provider Type Distribution')
plt.xlabel('Provider Type')
plt.ylabel('Count')
plt.show()

# %%
sns.barplot(y=provider_distribution.index, x=provider_distribution.values, palette='viridis')
plt.title('Provider Type Distribution')
plt.xlabel('Count')
plt.ylabel('Provider Type')
plt.show()

# %%
# Calculate percentage distribution
provider_percentage = provider_distribution / provider_distribution.sum() * 100
print(provider_percentage)

# %%
# Inspect the first few rows to identify relevant columns
df.head()

# Check for gender column and relevant metrics
print(df.columns)

# Ensure there are no missing values in the gender column
missing_gender = df['Gender'].isnull().sum()
print(f"Missing values in Gender column: {missing_gender}")

# %%
# Check unique values in the Gender column
print(df['Gender'].unique())

# Standardize gender values if necessary
df['Gender'] = df['Gender'].str.strip().str.lower().replace({
    'm': 'male', 'f': 'female', 'other': 'non-binary', '': 'unknown'
})

# %%
# Count occurrences of each gender
gender_distribution = df['Gender'].value_counts()

# Calculate percentages
gender_percentage = df['Gender'].value_counts(normalize=True) * 100

print("Gender Distribution:\n", gender_distribution)
print("\nGender Percentage:\n", gender_percentage)

# Visualize the gender balance
import matplotlib.pyplot as plt

gender_distribution.plot(kind='bar', color=['blue', 'pink', 'green', 'gray'], figsize=(8, 5), title='Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
