# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Task 7: Correlation Analysis
#
# Objective: Identify relationships between key metrics
#
# Tasks:
#
# 1. Compute a correlation matrix for numeric variables (eg, Number of Services, Av erage Medicare Payment. Amount).
#
# 2. Focus on strong correlations (eg, service volumes ve payments)
#
# Visualizations:
#
# Heatmap: Correlation matrix of numerical variables
#
# Pair plot Relationships between key financial and service metrics.
#
# Actionable Insight: Suggest features for downstream analyses or predictive modeling

# %%
# Assuming your dataset is loaded
data = pd.read_csv('Healthcare Providers.csv')

# %%
# Display available column names
print(data.columns)
# Out:
# Index(['index', 'National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
# Select numeric columns for correlation analysis
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# %%
# If no numeric columns, notify the user
if numeric_data.empty:
    print("No numeric columns found for correlation analysis.")
else:
    # Compute the correlation matrix
    correlation_matrix = numeric_data.corr()

    # Display the correlation matrix
    print("Correlation Matrix:")
    print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                  index  National Provider Identifier  \
# index                         1.000000                      0.999917
# National Provider Identifier  0.999917                      1.000000
# Zip Code of the Provider      0.001184                      0.001047
#
#                               Zip Code of the Provider
# index                                         0.001184
# National Provider Identifier                  0.001047
# Zip Code of the Provider                      1.000000

# %%
# Visualize the correlation matrix as a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', cbar=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Pair plot (if at least two numeric columns are present)
if len(numeric_data.columns) > 1:
    sns.pairplot(numeric_data, diag_kind='kde', corner=True)
    plt.suptitle('Pair Plot of Numeric Variables', y=1.02)
    plt.show()
else:
    print("Not enough numeric columns for pair plot.")
