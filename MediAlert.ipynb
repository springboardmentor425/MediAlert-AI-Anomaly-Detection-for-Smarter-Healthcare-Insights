# %%
import pandas as pd

# %%
file_path = 'C:/Users/Admin/Downloads/archive/Healthcare Providers.csv'
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# 3                            NaN                          MD
# 4                              E                          DO
#
#   Gender of the Provider Entity Type of the Provider  \
# 0                      F                           I
# 1                      F                           I
# 2                      M                           I
# 3                      M                           I
# 4                      M                           I
#
#   Street Address 1 of the Provider Street Address 2 of the Provider  ...  \
# 0                1402 S GRAND BLVD                   FDT 14TH FLOOR  ...
# 1                  2950 VILLAGE DR                              NaN  ...
# 2                20 WASHINGTON AVE                          STE 212  ...
# 3               5746 N BROADWAY ST                              NaN  ...
# 4                 875 MILITARY TRL                        SUITE 200  ...
#
#   HCPCS Code                                  HCPCS Description  \
# 0      99223  Initial hospital inpatient care, typically 70 ...
# 1      G0202  Screening mammography, bilateral (2-view study...
# 2      99348  Established patient home visit, typically 25 m...
# 3      81002                            Urinalysis, manual test
# 4      96372  Injection beneath the skin or into muscle for ...
#
#   HCPCS Drug Indicator Number of Services Number of Medicare Beneficiaries  \
# 0                    N                 27                               24
# 1                    N                175                              175
# 2                    N                 32                               13
# 3                    N                 20                               18
# 4                    N                 33                               24
#
#   Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                 27
# 1                                                175
# 2                                                 32
# 3                                                 20
# 4                                                 31
#
#   Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                    200.58777778                    305.21111111
# 1                          123.73                           548.8
# 2                           90.65                             155
# 3                             3.5                               5
# 4                           26.52                              40
#
#   Average Medicare Payment Amount Average Medicare Standardized Amount
# 0                    157.26222222                         160.90888889
# 1                          118.83                         135.31525714
# 2                      64.4396875                           60.5959375
# 3                            3.43                                 3.43
# 4                    19.539393939                         19.057575758
#
# [5 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   index                                                     100000 non-null  int64
#  1   National Provider Identifier                              100000 non-null  int64
#  2   Last Name/Organization Name of the Provider               100000 non-null  object
#  3   First Name of the Provider                                95745 non-null   object
#  4   Middle Initial of the Provider                            70669 non-null   object
#  5   Credentials of the Provider                               92791 non-null   object
#  6   Gender of the Provider                                    95746 non-null   object
#  7   Entity Type of the Provider                               100000 non-null  object
#  8   Street Address 1 of the Provider                          100000 non-null  object
#  9   Street Address 2 of the Provider                          40637 non-null   object
#  10  City of the Provider                                      100000 non-null  object
#  11  Zip Code of the Provider                                  100000 non-null  float64
#  12  State Code of the Provider                                100000 non-null  object
#  13  Country Code of the Provider                              100000 non-null  object
#  14  Provider Type                                             100000 non-null  object
#  15  Medicare Participation Indicator                          100000 non-null  object
#  16  Place of Service                                          100000 non-null  object
#  17  HCPCS Code                                                100000 non-null  object
#  18  HCPCS Description                                         100000 non-null  object
#  19  HCPCS Drug Indicator                                      100000 non-null  object
#  20  Number of Services                                        100000 non-null  object
#  21  Number of Medicare Beneficiaries                          100000 non-null  object
#  22  Number of Distinct Medicare Beneficiary/Per Day Services  100000 non-null  object
#  23  Average Medicare Allowed Amount                           100000 non-null  object
#  24  Average Submitted Charge Amount                           100000 non-null  object
#  25  Average Medicare Payment Amount                           100000 non-null  object
#  26  Average Medicare Standardized Amount                      100000 non-null  object
# dtypes: float64(1), int64(2), object(24)
# memory usage: 20.6+ MB

# %%
data.describe()
# Out:
#               index  National Provider Identifier  Zip Code of the Provider
# count  1.000000e+05                  1.000000e+05              1.000000e+05
# mean   4.907646e+06                  1.498227e+09              4.163820e+08
# std    2.839633e+06                  2.874125e+08              3.082566e+08
# min    2.090000e+02                  1.003001e+09              6.010000e+02
# 25%    2.458791e+06                  1.245669e+09              1.426300e+08
# 50%    4.901266e+06                  1.497847e+09              3.633025e+08
# 75%    7.349450e+06                  1.740374e+09              6.819881e+08
# max    9.847440e+06                  1.993000e+09              9.990166e+08

# %%
missing_values = data.isnull().sum()
missing_percentages = (missing_values / len(data)) * 100
missing_data = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentages
})
missing_data[missing_data['Missing Values'] > 0]
# Out:
#                                   Missing Values  Percentage
# First Name of the Provider                  4255       4.255
# Middle Initial of the Provider             29331      29.331
# Credentials of the Provider                 7209       7.209
# Gender of the Provider                      4254       4.254
# Street Address 2 of the Provider           59363      59.363

# %%
data.columns
for column in data.columns:
    print(f"{column} - Unique Values:\n", data[column].unique())
    print("\n")
# Out:
# index - Unique Values:
#  [8774979 3354385 3001884 ... 8927965 8854571 3547535]
#
#
# National Provider Identifier - Unique Values:
#  [1891106191 1346202256 1306820956 ... 1215091327 1891941183 1356772156]
#
#
# Last Name/Organization Name of the Provider - Unique Values:
#  ['UPADHYAYULA' 'JONES' 'DUROCHER' ... 'PAPES' 'GONZALEZ-LAMOS' 'RAMEZANI']
#
#
# First Name of the Provider - Unique Values:
#  ['SATYASREE' 'WENDY' 'RICHARD' ... 'ILIE' 'RAFAELA' 'ELIIAN']
#
#
# Middle Initial of the Provider - Unique Values:
#  [nan 'P' 'W' 'E' 'R' 'B' 'G' 'M' 'S' 'J' 'K' 'X' 'A' 'H' 'V' 'D' 'N' 'L'
#  'C' 'T' 'F' 'I' 'O' 'U' 'Y' 'Z' 'Q' '(' '.' '-']
#
#
# Credentials of the Provider - Unique Values:
#  ['M.D.' 'DPM' 'MD' ... 'DNP FNP-BC' 'MRCP, MD' 'PT,DPTATC']
#
#
# Gender of the Provider - Unique Values:
#  ['F' 'M' nan]
#
#
# Entity Type of the Provider - Unique Values:
#  ['I' 'O']
#
#
# Street Address 1 of the Provider - Unique Values:
#  ['1402 S GRAND BLVD' '2950 VILLAGE DR' '20 WASHINGTON AVE' ...
#  '324 E BALTIMORE ST' '645 NW 4TH ST' '444 MIDDLE NECK RD APT 1H']
#
#
# Street Address 2 of the Provider - Unique Values:
#  ['FDT 14TH FLOOR' nan 'STE 212' ... 'YKHC' '60 PROSPECT ST' '# 336']
#
#
# City of the Provider - Unique Values:
#  ['SAINT LOUIS' 'FAYETTEVILLE' 'NORTH HAVEN' ... 'SALIDA' 'PLATTSBURG'
#  'HOOPER BAY']
#
#
# Zip Code of the Provider - Unique Values:
#  [6.31041004e+08 2.83043815e+08 6.47323430e+07 ... 6.04811236e+08
#  9.77561502e+08 1.10230000e+04]
#
#
# State Code of the Provider - Unique Values:
#  ['MO' 'NC' 'CT' 'FL' 'VA' 'CA' 'CO' 'PA' 'AZ' 'KY' 'DC' 'WA' 'TX' 'NJ'
#  'MD' 'LA' 'OH' 'NY' 'GU' 'IL' 'OK' 'SC' 'MA' 'GA' 'IN' 'ME' 'MT' 'WI'
#  'AL' 'OR' 'NH' 'KS' 'MI' 'ID' 'MS' 'MN' 'TN' 'IA' 'NE' 'AK' 'ZZ' 'VT'
#  'NV' 'AR' 'WV' 'HI' 'RI' 'SD' 'PR' 'UT' 'NM' 'ND' 'DE' 'WY' 'VI' 'AE'
#  'AP' 'AA']
#
#
# Country Code of the Provider - Unique Values:
#  ['US' 'JP' 'DE' 'TR']
#
#
# Provider Type - Unique Values:
#  ['Internal Medicine' 'Obstetrics & Gynecology' 'Podiatry'
#  'Physical Therapist in Private Practice' 'Diagnostic Radiology'
#  'Family Practice' 'Clinical Laboratory' 'General Surgery'
#  'Pain Management' 'Physician Assistant' 'Cardiology' 'Anesthesiology'
#  'Gastroenterology' 'Psychiatry' 'Nurse Practitioner' 'General Practice'
#  'Certified Registered Nurse Anesthetist (CRNA)'
#  'Mass Immunizer Roster Biller' 'Critical Care (Intensivists)'
#  'Audiologist' 'Allergy/ Immunology' 'Clinical Cardiac Electrophysiology'
#  'Pulmonary Disease' 'Neurology' 'Orthopedic Surgery' 'Infectious Disease'
#  'Medical Oncology' 'Geriatric Medicine' 'Chiropractic'
#  'Emergency Medicine' 'Psychologist, Clinical' 'Interventional Cardiology'
#  'Dermatology' 'Ambulatory Surgical Center' 'Ophthalmology'
#  'Hematology-Oncology' 'Urology' 'Optometry' 'Vascular Surgery'
#  'Pathology' 'Thoracic Surgery' 'Nephrology'
#  'Physical Medicine and Rehabilitation' 'Neurosurgery'
#  'Ambulance Service Provider' 'Centralized Flu' 'Otolaryngology'
#  'Rheumatology' 'Cardiac Surgery'
#  'Independent Diagnostic Testing Facility (IDTF)' 'Hospitalist'
#  'Occupational Therapist in Private Practice' 'Radiation Oncology'
#  'Plastic and Reconstructive Surgery' 'Portable X-Ray Supplier'
#  'Endocrinology' 'Oral Surgery (Dentist only)'
#  'Interventional Pain Management' 'Hand Surgery' 'Nuclear Medicine'
#  'Hospice and Palliative Care' 'Maxillofacial Surgery' 'Hematology'
#  'Pediatric Medicine' 'Licensed Clinical Social Worker'
#  'Colorectal Surgery (Proctology)' 'Sleep Medicine'
#  'Interventional Radiology' 'Anesthesiology Assistant'
#  'Certified Clinical Nurse Specialist' 'All Other Suppliers'
#  'Gynecological Oncology' 'Sports Medicine' 'Surgical Oncology'
#  'Registered Dietitian or Nutrition Professional'
#  'Speech Language Pathologist' 'Addiction Medicine'
#  'Osteopathic Manipulative Medicine' 'Undefined Physician type'
#  'Public Health or Welfare Agency' 'Clinic or Group Practice'
#  'Preventive Medicine' 'Certified Nurse Midwife' 'Geriatric Psychiatry'
#  'Neuropsychiatry' 'Radiation Therapy Center' 'Pharmacy'
#  'Peripheral Vascular Disease'
#  'Advanced Heart Failure and Transplant Cardiology' 'Mammography Center']
#
#
# Medicare Participation Indicator - Unique Values:
#  ['Y' 'N']
#
#
# Place of Service - Unique Values:
#  ['F' 'O']
#
#
# HCPCS Code - Unique Values:
#  ['99223' 'G0202' '99348' ... '43247' '33530' '52001']
#
#
# HCPCS Description - Unique Values:
#  ['Initial hospital inpatient care, typically 70 minutes per day'
#  'Screening mammography, bilateral (2-view study of each breast), including computer-aided detection (cad) when performed'
#  'Established patient home visit, typically 25 minutes' ...
#  'Removal of foreign bodies of esophagus, stomach, and/or upper small bowel using an endoscope'
#  'Reoperation of heart artery bypass or valve procedure more than 1 month after original operation'
#  'Irrigation and removal of multiple blood clots from bladder and bladder canal (urethra) using an endoscope']
#
#
# HCPCS Drug Indicator - Unique Values:
#  ['N' 'Y']
#
#
# Number of Services - Unique Values:
#  ['27' '175' '32' ... '43,000' '1,815' '2,265']
#
#
# Number of Medicare Beneficiaries - Unique Values:
#  ['24' '175' '13' ... '1,097' '923' '2,995']
#
#
# Number of Distinct Medicare Beneficiary/Per Day Services - Unique Values:
#  ['27' '175' '32' ... '1,397' '1,815' '2,265']
#
#
# Average Medicare Allowed Amount - Unique Values:
#  ['200.58777778' '123.73' '90.65' ... '0.655' '85.3725' '38.601052632']
#
#
# Average Submitted Charge Amount - Unique Values:
#  ['305.21111111' '548.8' '155' ... '144.05147059' '109.54545455'
#  '46.867572156']
#
#
# Average Medicare Payment Amount - Unique Values:
#  ['157.26222222' '118.83' '64.4396875' ... '60.7255' '30.006176471'
#  '29.736876061']
#
#
# Average Medicare Standardized Amount - Unique Values:
#  ['160.90888889' '135.31525714' '60.5959375' ... '62.2485' '37.040220588'
#  '25.912139219']

# %%
# !pip install pandas matplotlib seaborn openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\admin\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: openpyxl in c:\users\admin\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\admin\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
file_path = 'C:/Users/Admin/Downloads/archive/Healthcare Providers.csv'
data = pd.read_csv(file_path)
print(data.head())
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# 3                            NaN                          MD
# 4                              E                          DO
#
#   Gender of the Provider Entity Type of the Provider  \
# 0                      F                           I
# 1                      F                           I
# 2                      M                           I
# 3                      M                           I
# 4                      M                           I
#
#   Street Address 1 of the Provider Street Address 2 of the Provider  ...  \
# 0                1402 S GRAND BLVD                   FDT 14TH FLOOR  ...
# 1                  2950 VILLAGE DR                              NaN  ...
# 2                20 WASHINGTON AVE                          STE 212  ...
# 3               5746 N BROADWAY ST                              NaN  ...
# 4                 875 MILITARY TRL                        SUITE 200  ...
#
#   HCPCS Code                                  HCPCS Description  \
# 0      99223  Initial hospital inpatient care, typically 70 ...
# 1      G0202  Screening mammography, bilateral (2-view study...
# 2      99348  Established patient home visit, typically 25 m...
# 3      81002                            Urinalysis, manual test
# 4      96372  Injection beneath the skin or into muscle for ...
#
#   HCPCS Drug Indicator Number of Services Number of Medicare Beneficiaries  \
# 0                    N                 27                               24
# 1                    N                175                              175
# 2                    N                 32                               13
# 3                    N                 20                               18
# 4                    N                 33                               24
#
#   Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                 27
# 1                                                175
# 2                                                 32
# 3                                                 20
# 4                                                 31
#
#   Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                    200.58777778                    305.21111111
# 1                          123.73                           548.8
# 2                           90.65                             155
# 3                             3.5                               5
# 4                           26.52                              40
#
#   Average Medicare Payment Amount Average Medicare Standardized Amount
# 0                    157.26222222                         160.90888889
# 1                          118.83                         135.31525714
# 2                      64.4396875                           60.5959375
# 3                            3.43                                 3.43
# 4                    19.539393939                         19.057575758
#
# [5 rows x 27 columns]

# %%
print(data.describe())
# Out:
#               index  National Provider Identifier  Zip Code of the Provider
# count  1.000000e+05                  1.000000e+05              1.000000e+05
# mean   4.907646e+06                  1.498227e+09              4.163820e+08
# std    2.839633e+06                  2.874125e+08              3.082566e+08
# min    2.090000e+02                  1.003001e+09              6.010000e+02
# 25%    2.458791e+06                  1.245669e+09              1.426300e+08
# 50%    4.901266e+06                  1.497847e+09              3.633025e+08
# 75%    7.349450e+06                  1.740374e+09              6.819881e+08
# max    9.847440e+06                  1.993000e+09              9.990166e+08

# %%
for col in data.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 for col in data.select_dtypes(include=['float64', 'int64']).columns:
# ----> 2     plt.figure(figsize=(6, 4))
#       3     sns.histplot(data[col], kde=True, bins=30)
#       4     plt.title(f"Distribution of {col}")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
for col in data.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 for col in data.select_dtypes(include=['float64', 'int64']).columns:
#       2     plt.figure(figsize=(6, 4))
# ----> 3     sns.histplot(data[col], kde=True, bins=30)
#       4     plt.title(f"Distribution of {col}")
#       5     plt.show()
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns

# %%
for col in data.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
for col in data.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=data[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
for col in data.select_dtypes(include=['object']).columns:
    print(f"Value counts for {col}:\n", data[col].value_counts(), "\n")
# Out:
# Value counts for Last Name/Organization Name of the Provider:
#  Last Name/Organization Name of the Provider
# PATEL          557
# SMITH          491
# JOHNSON        372
# WALGREEN CO    362
# LEE            361
#               ...
# SHUE             1
# STANDRIDGE       1
# SIMCOE           1
# KENNESON         1
# RAMEZANI         1
# Name: count, Length: 42820, dtype: int64
#
# Value counts for First Name of the Provider:
#  First Name of the Provider
# MICHAEL     2350
# JOHN        2285
# DAVID       2239
# ROBERT      1872
# JAMES       1647
#             ...
# PACIFICO       1
# NANTHA         1
# SAMUAL         1
# DENAYE         1
# ELIIAN         1
# Name: count, Length: 13022, dtype: int64
#
# Value counts for Middle Initial of the Provider:
#  Middle Initial of the Provider
# A    8152
# M    7212
# J    6582
# L    5275
# S    4652
# R    4399
# D    4043
# E    3879
# C    3786
# B    2738
# K    2620
# W    2566
# P    2533
# H    2266
# T    2107
# G    2062
# F    1580
# N    1417
# V     839
# I     667
# Y     454
# O     433
# Z     148
# U     126
# Q      88
# X      40
# -       3
# (       1
# .       1
# Name: count, dtype: int64
#
# Value counts for Credentials of the Provider:
#  Credentials of the Provider
# MD                    32874
# M.D.                  32757
# D.O.                   3533
# DO                     2478
# PA-C                   1859
#                       ...
# DPT MFS                   1
# PT, CERT. MDT, NCS        1
# MD FAAFP FACEP            1
# PT, DPT, MS               1
# PT,DPTATC                 1
# Name: count, Length: 1854, dtype: int64
#
# Value counts for Gender of the Provider:
#  Gender of the Provider
# M    66641
# F    29105
# Name: count, dtype: int64
#
# Value counts for Entity Type of the Provider:
#  Entity Type of the Provider
# I    95746
# O     4254
# Name: count, dtype: int64
#
# Value counts for Street Address 1 of the Provider:
#  Street Address 1 of the Provider
# 200 1ST ST SW                244
# 9500 EUCLID AVE              153
# 200 HAWKINS DR               104
# 5323 HARRY HINES BLVD        104
# 75 FRANCIS ST                102
#                             ...
# 390 17TH ST NW                 1
# 1739 N OCEAN AVE STE A         1
# 24750 STUART PLACE RD          1
# 6490 S. MCCARRAN BLVD          1
# 444 MIDDLE NECK RD APT 1H      1
# Name: count, Length: 51928, dtype: int64
#
# Value counts for Street Address 2 of the Provider:
#  Street Address 2 of the Provider
# SUITE 200                    1624
# SUITE 100                    1524
# SUITE 101                     780
# SUITE 300                     740
# SUITE A                       702
#                              ...
# COGENT INPATIENT SERVICES       1
# BUILDING 4, SUITE G             1
# BUILDING 14A                    1
# SUITE A20                       1
# # 336                           1
# Name: count, Length: 10024, dtype: int64
#
# Value counts for City of the Provider:
#  City of the Provider
# NEW YORK          1061
# HOUSTON            874
# CHICAGO            759
# PHILADELPHIA       658
# BOSTON             634
#                   ...
# PASS CHRISTIAN       1
# BLUFF CITY           1
# HAWLEY               1
# PEYTON               1
# HOOPER BAY           1
# Name: count, Length: 5846, dtype: int64
#
# Value counts for State Code of the Provider:
#  State Code of the Provider
# CA    7775
# FL    7263
# TX    6861
# NY    6361
# PA    4561
# IL    4073
# NC    3725
# OH    3663
# MI    3516
# NJ    3333
# GA    2858
# VA    2792
# MA    2791
# TN    2673
# IN    2203
# MD    2076
# WA    2020
# MO    1997
# AZ    1994
# WI    1840
# AL    1821
# SC    1753
# KY    1667
# MN    1563
# LA    1520
# CO    1423
# CT    1403
# OK    1250
# IA    1136
# AR    1130
# KS    1109
# MS    1108
# OR    1046
# NE     787
# NV     707
# WV     644
# UT     640
# NH     547
# ME     466
# NM     421
# ID     415
# DE     378
# RI     359
# MT     345
# SD     326
# PR     284
# DC     275
# HI     249
# VT     239
# ND     231
# WY     171
# AK     165
# VI      20
# GU      15
# ZZ       6
# AP       3
# AE       2
# AA       1
# Name: count, dtype: int64
#
# Value counts for Country Code of the Provider:
#  Country Code of the Provider
# US    99994
# DE        3
# JP        2
# TR        1
# Name: count, dtype: int64
#
# Value counts for Provider Type:
#  Provider Type
# Diagnostic Radiology                                12537
# Internal Medicine                                   11366
# Family Practice                                      9760
# Nurse Practitioner                                   5713
# Cardiology                                           4602
#                                                     ...
# Certified Nurse Midwife                                 7
# Radiation Therapy Center                                3
# Mammography Center                                      3
# Pharmacy                                                1
# Advanced Heart Failure and Transplant Cardiology        1
# Name: count, Length: 90, dtype: int64
#
# Value counts for Medicare Participation Indicator:
#  Medicare Participation Indicator
# Y    99969
# N       31
# Name: count, dtype: int64
#
# Value counts for Place of Service:
#  Place of Service
# O    61616
# F    38384
# Name: count, dtype: int64
#
# Value counts for HCPCS Code:
#  HCPCS Code
# 99213    4578
# 99214    4401
# 99232    1851
# 99203    1846
# 99204    1743
#          ...
# 80159       1
# J0780       1
# 25111       1
# 86682       1
# 52001       1
# Name: count, Length: 2631, dtype: int64
#
# Value counts for HCPCS Description:
#  HCPCS Description
# Established patient office or other outpatient visit, typically 15 minutes                                    4578
# Established patient office or other outpatient, visit typically 25 minutes                                    4401
# Subsequent hospital inpatient care, typically 25 minutes per day                                              1851
# New patient office or other outpatient visit, typically 30 minutes                                            1846
# New patient office or other outpatient visit, typically 45 minutes                                            1743
#                                                                                                               ...
# Injection of vocal cords using an endoscope with operating microscope or telescope                               1
# Closed treatment of broken great toe                                                                             1
# White blood cell alkaline phosphatase (enzyme) measurement with cell count                                       1
# Management of radiation therapy, simulation, intermediate                                                        1
# Irrigation and removal of multiple blood clots from bladder and bladder canal (urethra) using an endoscope       1
# Name: count, Length: 2455, dtype: int64
#
# Value counts for HCPCS Drug Indicator:
#  HCPCS Drug Indicator
# N    93802
# Y     6198
# Name: count, dtype: int64
#
# Value counts for Number of Services:
#  Number of Services
# 13       3018
# 12       2967
# 11       2810
# 14       2789
# 15       2622
#          ...
# 8,613       1
# 5,173       1
# 2,073       1
# 457.3       1
# 2,265       1
# Name: count, Length: 2748, dtype: int64
#
# Value counts for Number of Medicare Beneficiaries:
#  Number of Medicare Beneficiaries
# 11       4791
# 12       4272
# 13       3922
# 14       3523
# 15       3260
#          ...
# 1,182       1
# 1,131       1
# 1,116       1
# 1,593       1
# 2,995       1
# Name: count, Length: 1274, dtype: int64
#
# Value counts for Number of Distinct Medicare Beneficiary/Per Day Services:
#  Number of Distinct Medicare Beneficiary/Per Day Services
# 12       3210
# 13       3171
# 11       3090
# 14       2912
# 15       2751
#          ...
# 1,139       1
# 1,380       1
# 1,298       1
# 3,899       1
# 2,265       1
# Name: count, Length: 1979, dtype: int64
#
# Value counts for Average Medicare Allowed Amount:
#  Average Medicare Allowed Amount
# 3               1017
# 3.08             441
# 13.32            417
# 3.5              406
# 5.39             356
#                 ...
# 10.316414141       1
# 522.33142857       1
# 62.443461538       1
# 2.6002941176       1
# 38.601052632       1
# Name: count, Length: 49629, dtype: int64
#
# Value counts for Average Submitted Charge Amount:
#  Average Submitted Charge Amount
# 150             970
# 50              967
# 30              868
# 100             859
# 25              842
#                ...
# 110.77697842      1
# 190.15702479      1
# 166.67            1
# 174.93670886      1
# 46.867572156      1
# Name: count, Length: 38088, dtype: int64
#
# Value counts for Average Medicare Payment Amount:
#  Average Medicare Payment Amount
# 2.94            623
# 3.02            335
# 3.43            320
# 13.05           292
# 18.65           290
#                ...
# 274.4547619       1
# 36.57382716       1
# 68.400816327      1
# 969.67923077      1
# 29.736876061      1
# Name: count, Length: 83367, dtype: int64
#
# Value counts for Average Medicare Standardized Amount:
#  Average Medicare Standardized Amount
# 25.32           1630
# 2.94             996
# 115.36           501
# 13.05            453
# 3.02             453
#                 ...
# 74.965194175       1
# 289.4196           1
# 61.359392625       1
# 22.228974359       1
# 25.912139219       1
# Name: count, Length: 76237, dtype: int64

# %%
for col in data.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=data[col], palette='viridis')
    plt.title(f"Count plot of {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6896\290809361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette='viridis')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6896\290809361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette='viridis')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6896\290809361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette='viridis')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6896\290809361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette='viridis')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6896\290809361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette='viridis')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6896\290809361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette='viridis')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6896\290809361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in data.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(data=data, x=col, palette='viridis', legend=False)  # Updated here
    plt.title(f"Count plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in data.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=data[col], palette='viridis')
    plt.title(f"Count plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in data.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=data[col], palette='viridis')
    plt.title(f"Count plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns
for col1 in numerical_cols:
    for col2 in numerical_cols:
        if col1 != col2:
            plt.figure(figsize=(6, 4))
            sns.scatterplot(x=data[col1], y=data[col2])
            plt.title(f"{col1} vs {col2}")
            plt.show()

# %%
for col in data.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=data[col])
    plt.title(f"Boxplot of {col}")
    plt.show()
