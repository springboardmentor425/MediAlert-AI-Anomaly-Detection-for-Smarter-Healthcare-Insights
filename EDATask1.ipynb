# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
# Load CSV file
df = pd.read_csv('Healthcare Providers.csv')

# View first few rows
df.head()
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# ...

# %%
a=df['First Name of the Provider'].isnull().sum()
print(a)
# Out:
# 4255

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# ...

# %%
df.columns
# Out:
# Index(['index', 'National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
# Display information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   index                                                     100000 non-null  int64
#  1   National Provider Identifier                              100000 non-null  int64
#  2   Last Name/Organization Name of the Provider               100000 non-null  object
#  3   First Name of the Provider                                95745 non-null   object
#  4   Middle Initial of the Provider                            70669 non-null   object
#  5   Credentials of the Provider                               92791 non-null   object
#  6   Gender of the Provider                                    95746 non-null   object
# ...

# %%
df.dtypes
# Out:
# index                                                         int64
# National Provider Identifier                                  int64
# Last Name/Organization Name of the Provider                  object
# First Name of the Provider                                   object
# Middle Initial of the Provider                               object
# Credentials of the Provider                                  object
# Gender of the Provider                                       object
# Entity Type of the Provider                                  object
# Street Address 1 of the Provider                             object
# Street Address 2 of the Provider                             object
# City of the Provider                                         object
# Zip Code of the Provider                                    float64
# State Code of the Provider                                   object
# Country Code of the Provider                                 object
# ...

# %%
# Display summary of missing values
print(df.isnull().sum())
# Out:
# index                                                           0
# National Provider Identifier                                    0
# Last Name/Organization Name of the Provider                     0
# First Name of the Provider                                   4255
# Middle Initial of the Provider                              29331
# Credentials of the Provider                                  7209
# Gender of the Provider                                       4254
# Entity Type of the Provider                                     0
# Street Address 1 of the Provider                                0
# Street Address 2 of the Provider                            59363
# City of the Provider                                            0
# Zip Code of the Provider                                        0
# State Code of the Provider                                      0
# Country Code of the Provider                                    0
# ...

# %%
print(df.count())
# Out:
# index                                                       100000
# National Provider Identifier                                100000
# Last Name/Organization Name of the Provider                 100000
# First Name of the Provider                                   95745
# Middle Initial of the Provider                               70669
# Credentials of the Provider                                  92791
# Gender of the Provider                                       95746
# Entity Type of the Provider                                 100000
# Street Address 1 of the Provider                            100000
# Street Address 2 of the Provider                             40637
# City of the Provider                                        100000
# Zip Code of the Provider                                    100000
# State Code of the Provider                                  100000
# Country Code of the Provider                                100000
# ...

# %%
print("Missing valuse")
missing_values=df.isnull().sum()
# print(missing_values)
percentages=(missing_values/len(df))*100
dataOfMissingValues=pd.DataFrame({'Missing_Values':missing_values,"Percentages":percentages})
dataOfMissingValues
# Out:
# Missing valuse
#                                                     Missing_Values  \
# index                                                            0
# National Provider Identifier                                     0
# Last Name/Organization Name of the Provider                      0
# First Name of the Provider                                    4255
# Middle Initial of the Provider                               29331
# Credentials of the Provider                                   7209
# Gender of the Provider                                        4254
# Entity Type of the Provider                                      0
# Street Address 1 of the Provider                                 0
# Street Address 2 of the Provider                             59363
# City of the Provider                                             0
# Zip Code of the Provider                                         0
# State Code of the Provider                                       0
# ...

# %%
df = df.drop(columns=['Street Address 2 of the Provider'])

# %%
# print(cleaned_data.isnull().sum())
df.isnull().sum()
# Out:
# index                                                           0
# National Provider Identifier                                    0
# Last Name/Organization Name of the Provider                     0
# First Name of the Provider                                   4255
# Middle Initial of the Provider                              29331
# Credentials of the Provider                                  7209
# Gender of the Provider                                       4254
# Entity Type of the Provider                                     0
# Street Address 1 of the Provider                                0
# City of the Provider                                            0
# Zip Code of the Provider                                        0
# State Code of the Provider                                      0
# Country Code of the Provider                                    0
# Provider Type                                                   0
# ...

# %%
#For numerical columns, fill with mean or median:
# df['Column_Name'].fillna(df['Column_Name'].mean(), inplace=True)

# %%
#For categorical columns, fill with mode or "Unknown"
df['First Name of the Provider']=df['First Name of the Provider'].fillna('Unknown')
df['Middle Initial of the Provider']=df['Middle Initial of the Provider'].fillna('Unknown')
df['Credentials of the Provider']=df['Credentials of the Provider'].fillna('Unknown')
df['Gender of the Provider']=df['Gender of the Provider'].fillna('Unknown')

# %%
print(df.isnull().sum())
# Out:
# index                                                       0
# National Provider Identifier                                0
# Last Name/Organization Name of the Provider                 0
# First Name of the Provider                                  0
# Middle Initial of the Provider                              0
# Credentials of the Provider                                 0
# Gender of the Provider                                      0
# Entity Type of the Provider                                 0
# Street Address 1 of the Provider                            0
# City of the Provider                                        0
# Zip Code of the Provider                                    0
# State Code of the Provider                                  0
# Country Code of the Provider                                0
# Provider Type                                               0
# Medicare Participation Indicator                            0
# ...

# %%
df
# Out:
#          index  National Provider Identifier  \
# 0      8774979                    1891106191
# 1      3354385                    1346202256
# 2      3001884                    1306820956
# 3      7594822                    1770523540
# 4       746159                    1073627758
# ...        ...                           ...
# 99995  3837311                    1386938868
# 99996  2079360                    1215091327
# 99997  8927965                    1902868185
# 99998  8854571                    1891941183
# 99999  3547535                    1356772156
#
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                     UPADHYAYULA                  SATYASREE
# 1                                           JONES                      WENDY
# 2                                        DUROCHER                    RICHARD
# 3                                         FULLARD                     JASPER
# ...

# %%
# Remove $ and convert to float
df['Average Medicare Allowed Amount'] = df['Average Medicare Allowed Amount'].str.replace('$', '').str.replace(',', '').astype(float)
df['Average Submitted Charge Amount'] = df['Average Submitted Charge Amount'].str.replace('$', '').str.replace(',', '').astype(float)
df['Average Medicare Payment Amount'] = df['Average Medicare Payment Amount'].str.replace('$', '').str.replace(',', '').astype(float)
df['Average Medicare Standardized Amount'] = df['Average Medicare Standardized Amount'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df.dtypes
# Out:
# index                                                         int64
# National Provider Identifier                                  int64
# Last Name/Organization Name of the Provider                  object
# First Name of the Provider                                   object
# Middle Initial of the Provider                               object
# Credentials of the Provider                                  object
# Gender of the Provider                                       object
# Entity Type of the Provider                                  object
# Street Address 1 of the Provider                             object
# City of the Provider                                         object
# Zip Code of the Provider                                    float64
# State Code of the Provider                                   object
# Country Code of the Provider                                 object
# Provider Type                                                object
# ...

# %%
print(df['Medicare Participation Indicator'])
# Out:
# 0        Y
# 1        Y
# 2        Y
# 3        Y
# 4        Y
#         ..
# 99995    Y
# 99996    Y
# 99997    Y
# 99998    Y
# 99999    Y
# Name: Medicare Participation Indicator, Length: 100000, dtype: object

# %%
for i in df.columns:
    print(i,'----->',df[i].unique())
    print()
# Out:
# index -----> [8774979 3354385 3001884 ... 8927965 8854571 3547535]
#
# National Provider Identifier -----> [1891106191 1346202256 1306820956 ... 1215091327 1891941183 1356772156]
#
# Last Name/Organization Name of the Provider -----> ['UPADHYAYULA' 'JONES' 'DUROCHER' ... 'PAPES' 'GONZALEZ-LAMOS' 'RAMEZANI']
#
# First Name of the Provider -----> ['SATYASREE' 'WENDY' 'RICHARD' ... 'ILIE' 'RAFAELA' 'ELIIAN']
#
# Middle Initial of the Provider -----> ['Unknown' 'P' 'W' 'E' 'R' 'B' 'G' 'M' 'S' 'J' 'K' 'X' 'A' 'H' 'V' 'D' 'N'
#  'L' 'C' 'T' 'F' 'I' 'O' 'U' 'Y' 'Z' 'Q' '(' '.' '-']
#
# Credentials of the Provider -----> ['M.D.' 'DPM' 'MD' ... 'DNP FNP-BC' 'MRCP, MD' 'PT,DPTATC']
#
# Gender of the Provider -----> ['F' 'M' 'Unknown']
#
# Entity Type of the Provider -----> ['I' 'O']
#
# Street Address 1 of the Provider -----> ['1402 S GRAND BLVD' '2950 VILLAGE DR' '20 WASHINGTON AVE' ...
#  '324 E BALTIMORE ST' '645 NW 4TH ST' '444 MIDDLE NECK RD APT 1H']
#
# ...

# %%
# ordinal
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Apply encoding to the column
df['Medicare Participation Indicator'] = le.fit_transform(df['Medicare Participation Indicator'])
df['HCPCS Drug Indicator'] = le.fit_transform(df['HCPCS Drug Indicator'])

# %%
# print(df['Medicare Participation Indicator'])
print(df['HCPCS Drug Indicator'])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: HCPCS Drug Indicator, Length: 100000, dtype: int64

# %%
# Convert categorical columns using LabelEncoder
categorical_columns = ['Gender of the Provider', 'Provider Type', 'Entity Type of the Provider', 'Place of Service']
for col in categorical_columns:
   df[col] = LabelEncoder().fit_transform(df[col])

# %%
df.dtypes
# Out:
# index                                                         int64
# National Provider Identifier                                  int64
# Last Name/Organization Name of the Provider                  object
# First Name of the Provider                                   object
# Middle Initial of the Provider                               object
# Credentials of the Provider                                  object
# Gender of the Provider                                        int64
# Entity Type of the Provider                                   int64
# Street Address 1 of the Provider                             object
# City of the Provider                                         object
# Zip Code of the Provider                                    float64
# State Code of the Provider                                   object
# Country Code of the Provider                                 object
# Provider Type                                                 int64
# ...

# %%
# Convert object columns to numeric
df['Number of Services'] = pd.to_numeric(df['Number of Services'], errors='coerce')
df['Number of Medicare Beneficiaries'] = pd.to_numeric(df['Number of Medicare Beneficiaries'], errors='coerce')
df['Number of Distinct Medicare Beneficiary/Per Day Services'] = pd.to_numeric(df['Number of Distinct Medicare Beneficiary/Per Day Services'], errors='coerce')

# %% [markdown]
#  if the column 'State Code of the Provider' contains values like ['NY', 'CA', 'TX'], it generates new binary columns:
# 'State Code of the Provider_NY'
# 'State Code of the Provider_CA'
# 'State Code of the Provider_TX'
#
#
# ### State_NY  State_CA  State_TX
# ### **1         0         0**
# ### **0         1         0**
# ### **0         0         1**

# %%
# One hot Encoding
df = pd.get_dummies(df, columns=['State Code of the Provider', 'Country Code of the Provider'], drop_first=True)

# %%
for i in df.columns:
    print(i)
# Out:
# index
# National Provider Identifier
# Last Name/Organization Name of the Provider
# First Name of the Provider
# Middle Initial of the Provider
# Credentials of the Provider
# Gender of the Provider
# Entity Type of the Provider
# Street Address 1 of the Provider
# City of the Provider
# Zip Code of the Provider
# Provider Type
# Medicare Participation Indicator
# Place of Service
# HCPCS Code
# HCPCS Description
# HCPCS Drug Indicator
# Number of Services
# Number of Medicare Beneficiaries
# Number of Distinct Medicare Beneficiary/Per Day Services
# Average Medicare Allowed Amount
# Average Submitted Charge Amount
# Average Medicare Payment Amount
# Average Medicare Standardized Amount
# State Code of the Provider_AE
# State Code of the Provider_AK
# State Code of the Provider_AL
# State Code of the Provider_AP
# State Code of the Provider_AR
# State Code of the Provider_AZ
# State Code of the Provider_CA
# State Code of the Provider_CO
# State Code of the Provider_CT
# ...

# %%
import matplotlib.pyplot as plt
print("from the above diagram at x-axies amount zero the frequency is high as nearly 100000")
# Plot histogram for 'Average Medicare Payment Amount'
plt.figure(figsize=(8, 6))
df['Average Medicare Payment Amount'].hist(bins=20, edgecolor='black')
plt.title('Distribution of Average Medicare Payment Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# from the above diagram at x-axies amount zero the frequency is high as nearly 100000

# %%
import seaborn as sns

# Plot boxplot for 'Average Medicare Payment Amount' to detect outliers
plt.figure(figsize=(8, 6))
sns.boxplot(data=df['Average Medicare Payment Amount'])
plt.title('Boxplot of Average Medicare Payment Amount')
plt.show()

# %%
# Plot correlation heatmap for the numerical columns
correlation_matrix = df[['Average Medicare Payment Amount', 'Average Medicare Allowed Amount', 'Zip Code of the Provider', 'Medicare Participation Indicator']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plot scatter plot to explore the relationship between 'Average Medicare Allowed Amount' and 'Average Medicare Payment Amount'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Average Medicare Allowed Amount', y='Average Medicare Payment Amount', data=df)
plt.title('Scatter Plot: Average Medicare Allowed Amount vs. Average Medicare Payment Amount')
plt.xlabel('Average Medicare Allowed Amount')
plt.ylabel('Average Medicare Payment Amount')
plt.show()

# %%
import matplotlib.pyplot as plt
print("from the above diagram at x-axies amount zero the frequency is high as nearly 100000")
# Plot histogram for 'Average Medicare Allowed Amount'
plt.figure(figsize=(8, 6))
df['Average Medicare Allowed Amount'].hist(bins=20, edgecolor='black')
plt.title('Distribution of Average Medicare Allowed Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# from the above diagram at x-axies amount zero the frequency is high as nearly 100000

# %%
import seaborn as sns

# Plot boxplot for 'Average Medicare Allowed Amount' to detect outliers
plt.figure(figsize=(8, 6))
sns.boxplot(data=df['Average Medicare Allowed Amount'])
plt.title('Boxplot of Average Medicare Allowed Amount')
plt.show()
